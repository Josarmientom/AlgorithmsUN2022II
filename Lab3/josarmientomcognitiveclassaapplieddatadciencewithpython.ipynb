# %% [markdown]
# <a href="https://colab.research.google.com/github/Josarmientom/AlgorithmsUN2022II/blob/main/Lab3/josarmientomcognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Linkedin:**  https://www.linkedin.com/in/joseph-nicolay-sarmiento-molano-3b1a1624b/
#
# ![image.png](data:image/png;base64,...)
